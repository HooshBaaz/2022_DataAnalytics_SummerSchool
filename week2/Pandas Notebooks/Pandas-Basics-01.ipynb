# %% [markdown]
# # Pandas Basics

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## What Is DataFrame? How To Create It?

# %%
data_dict = {
    'car_name': ['pride', 'peykan', 'bmw', 'lexus', 'cerato', 'l90'],
    'price': [100, 50, 2000, 1600, 1200, 900],
    'quality': [-1, -2, 5, 4, 3, 2]
}

df = pd.DataFrame(data_dict)
df  # index is automatically generated
# Out:
#   car_name  price  quality
# 0    pride    100       -1
# 1   peykan     50       -2
# 2      bmw   2000        5
# 3    lexus   1600        4
# 4   cerato   1200        3
# 5      l90    900        2

# %%
car_names = ['pride', 'peykan', 'bmw', 'lexus', 'cerato', 'l90']
price = [100, 50, 2000, 1600, 1200, 900]
quality = [-1, -2, 5, 4, 3, 2]
# data_list = list(zip(car_names, price, quality))
data_list = list(zip(car_names, price, quality))
print(data_list)

df = pd.DataFrame(data_list)
df.head()  # auto-generated index and improper column names
# Out:
# [('pride', 100, -1), ('peykan', 50, -2), ('bmw', 2000, 5), ('lexus', 1600, 4), ('cerato', 1200, 3), ('l90', 900, 2)]
#         0     1  2
# 0   pride   100 -1
# 1  peykan    50 -2
# 2     bmw  2000  5
# 3   lexus  1600  4
# 4  cerato  1200  3

# %%
df = pd.DataFrame(data_list, columns=['car_name', 'price', 'quality'])
df = df.set_index('car_name')
df.head(3)
# Out:
#           price  quality
# car_name
# pride       100       -1
# peykan       50       -2
# bmw        2000        5

# %% [markdown]
# ## Pandas Vs. Numpy

# %%
price_np = np.array(price)
print(price_np)     # No index

df['price']         # Each element has an index which is the name of a car
                    # This makes it much easier to work with data.
# Out:
# [ 100   50 2000 1600 1200  900]
# car_name
# pride      100
# peykan      50
# bmw       2000
# lexus     1600
# cerato    1200
# l90        900
# Name: price, dtype: int64

# %% [markdown]
# ## Loading A Dataset

# %%
df = pd.read_excel('covid.xlsx')        # read_csv() for csv files
df.head()
# Out:
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-12-14   14     12  2020    746       6             Afghanistan    AF
# 1 2020-12-13   13     12  2020    298       9             Afghanistan    AF
# 2 2020-12-12   12     12  2020    113      11             Afghanistan    AF
# 3 2020-12-11   11     12  2020     63      10             Afghanistan    AF
# 4 2020-12-10   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# 2                                           6.868768
# 3                                           7.134266
# 4                                           6.968658

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61900 entries, 0 to 61899
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     61900 non-null  datetime64[ns]
#  1   day                                                         61900 non-null  int64
#  2   month                                                       61900 non-null  int64
#  3   year                                                        61900 non-null  int64
#  4   cases                                                       61900 non-null  int64
#  5   deaths                                                      61900 non-null  int64
#  6   countriesAndTerritories                                     61900 non-null  object
#  7   geoId                                                       61625 non-null  object
#  8   countryterritoryCode                                        61777 non-null  object
#  9   popData2019                                                 61777 non-null  float64
#  10  continentExp                                                61900 non-null  object
#  11  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000  59021 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(5), object(4)
# memory usage: 5.7+ MB

# %% [markdown]
# ## Selecting By Columns

# %%
# df.countriesAndTerritories
df['countriesAndTerritories']
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 61895       Zimbabwe
# 61896       Zimbabwe
# 61897       Zimbabwe
# 61898       Zimbabwe
# 61899       Zimbabwe
# Name: countriesAndTerritories, Length: 61900, dtype: object

# %%
# selecting multiple columns
df_countries_cases = df[['countriesAndTerritories', 'cases', 'dateRep']]
df_countries_cases.tail()
# Out:
#       countriesAndTerritories  cases    dateRep
# 61895                Zimbabwe      0 2020-03-25
# 61896                Zimbabwe      0 2020-03-24
# 61897                Zimbabwe      0 2020-03-23
# 61898                Zimbabwe      1 2020-03-22
# 61899                Zimbabwe      1 2020-03-21

# %%
# selecting based on condition
df_iran = df[(df.countriesAndTerritories == 'Iran')]
print(df.countriesAndTerritories == 'Iran')
print('-----------------------------------')
df_iran
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 61895    False
# 61896    False
# 61897    False
# 61898    False
# 61899    False
# Name: countriesAndTerritories, Length: 61900, dtype: bool
# -----------------------------------
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 27437 2020-12-14   14     12  2020   7451     247                    Iran
# 27438 2020-12-13   13     12  2020   8201     221                    Iran
# 27439 2020-12-12   12     12  2020   9594     232                    Iran
# 27440 2020-12-11   11     12  2020  10403     284                    Iran
# 27441 2020-12-10   10     12  2020  10223     295                    Iran
# ...          ...  ...    ...   ...    ...     ...                     ...
# 27782 2020-01-04    4      1  2020      0       0                    Iran
# 27783 2020-01-03    3      1  2020      0       0                    Iran
# 27784 2020-01-02    2      1  2020      0       0                    Iran
# 27785 2020-01-01    1      1  2020      0       0                    Iran
# 27786 2019-12-31   31     12  2019      0       0                    Iran
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 27437    IR                  IRN   82913893.0         Asia
# 27438    IR                  IRN   82913893.0         Asia
# 27439    IR                  IRN   82913893.0         Asia
# 27440    IR                  IRN   82913893.0         Asia
# 27441    IR                  IRN   82913893.0         Asia
# ...     ...                  ...          ...          ...
# 27782    IR                  IRN   82913893.0         Asia
# 27783    IR                  IRN   82913893.0         Asia
# 27784    IR                  IRN   82913893.0         Asia
# 27785    IR                  IRN   82913893.0         Asia
# 27786    IR                  IRN   82913893.0         Asia
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 27437                                         192.392365
# 27438                                         199.024547
# 27439                                         205.297320
# 27440                                         210.672776
# 27441                                         214.963975
# ...                                                  ...
# 27782                                                NaN
# 27783                                                NaN
# 27784                                                NaN
# 27785                                                NaN
# 27786                                                NaN
#
# [350 rows x 12 columns]

# %% [markdown]
# ## Selecting By Index/Label

# %%
# syntax: df.loc[row selector, column selector]
df_iran.loc[27437:27441, ]    # or, df_iran.loc[27437:27441, :], or df_iran.loc[27437:27441, ]
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 27440 2020-12-11   11     12  2020  10403     284                    Iran
# 27441 2020-12-10   10     12  2020  10223     295                    Iran
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 27440    IR                  IRN   82913893.0         Asia
# 27441    IR                  IRN   82913893.0         Asia
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 27440                                         210.672776
# 27441                                         214.963975

# %%
df_iran.loc[27437:27441, 'dateRep':'deaths']       # in Pandas, both ends of ranges are included in selection
# Out:
#          dateRep  day  month  year  cases  deaths
# 27440 2020-12-11   11     12  2020  10403     284
# 27441 2020-12-10   10     12  2020  10223     295

# %%
# these indices are a bit hard to work with. we can use numerical index
print(df_iran.iloc[:5, 1:4])
# print(df_iran.iloc[:5, ['day', 'month', 'year']])      # iloc only accepts numerical indices!!
# Out:
#        day  month  year
# 27440   11     12  2020
# 27441   10     12  2020
# 27442    9     12  2020
# 27443    8     12  2020
# 27444    7     12  2020

# %% [markdown]
# ## df.where() vs. Conditional Selection

# %%
# Notice the size of the resulting dataframe
df_iran[df_iran.cases > 3000]
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 27440 2020-12-11   11     12  2020  10403     284                    Iran
# 27441 2020-12-10   10     12  2020  10223     295                    Iran
# 27442 2020-12-09    9     12  2020  11023     323                    Iran
# 27443 2020-12-08    8     12  2020  10827     284                    Iran
# 27444 2020-12-07    7     12  2020  11561     294                    Iran
# 27445 2020-12-06    6     12  2020  12151     321                    Iran
# 27446 2020-12-05    5     12  2020  13341     347                    Iran
# 27447 2020-12-04    4     12  2020  13922     358                    Iran
# 27448 2020-12-03    3     12  2020  13621     362                    Iran
# 27449 2020-12-02    2     12  2020  13881     382                    Iran
# 27450 2020-12-01    1     12  2020  13321     371                    Iran
# 27451 2020-11-30   30     11  2020  12950     389                    Iran
# 27452 2020-11-29   29     11  2020  13402     391                    Iran
# 27453 2020-11-28   28     11  2020  14051     406                    Iran
# 27454 2020-11-27   27     11  2020  13961     482                    Iran
# 27457 2020-11-24   24     11  2020  12460     453                    Iran
# 27458 2020-11-23   23     11  2020  13053     475                    Iran
# 27459 2020-11-22   22     11  2020  12931     431                    Iran
# 27462 2020-11-19   19     11  2020  13421     480                    Iran
# 27463 2020-11-18   18     11  2020  13352     482                    Iran
# 27464 2020-11-17   17     11  2020  13053     486                    Iran
# 27465 2020-11-16   16     11  2020  12543     459                    Iran
# 27466 2020-11-15   15     11  2020  11203     452                    Iran
# 27467 2020-11-14   14     11  2020  11737     461                    Iran
# 27468 2020-11-13   13     11  2020  11517     457                    Iran
# 27469 2020-11-12   12     11  2020  11780     462                    Iran
# 27470 2020-11-11   11     11  2020  10339     453                    Iran
# 27471 2020-11-10   10     11  2020  10463     458                    Iran
#
#       geoId countryterritoryCode  popData2019 continentExp  \
# 27440    IR                  IRN   82913893.0         Asia
# 27441    IR                  IRN   82913893.0         Asia
# 27442    IR                  IRN   82913893.0         Asia
# 27443    IR                  IRN   82913893.0         Asia
# 27444    IR                  IRN   82913893.0         Asia
# 27445    IR                  IRN   82913893.0         Asia
# 27446    IR                  IRN   82913893.0         Asia
# 27447    IR                  IRN   82913893.0         Asia
# 27448    IR                  IRN   82913893.0         Asia
# 27449    IR                  IRN   82913893.0         Asia
# 27450    IR                  IRN   82913893.0         Asia
# 27451    IR                  IRN   82913893.0         Asia
# 27452    IR                  IRN   82913893.0         Asia
# 27453    IR                  IRN   82913893.0         Asia
# 27454    IR                  IRN   82913893.0         Asia
# 27457    IR                  IRN   82913893.0         Asia
# 27458    IR                  IRN   82913893.0         Asia
# 27459    IR                  IRN   82913893.0         Asia
# 27462    IR                  IRN   82913893.0         Asia
# 27463    IR                  IRN   82913893.0         Asia
# 27464    IR                  IRN   82913893.0         Asia
# 27465    IR                  IRN   82913893.0         Asia
# 27466    IR                  IRN   82913893.0         Asia
# 27467    IR                  IRN   82913893.0         Asia
# 27468    IR                  IRN   82913893.0         Asia
# 27469    IR                  IRN   82913893.0         Asia
# 27470    IR                  IRN   82913893.0         Asia
# 27471    IR                  IRN   82913893.0         Asia
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 27440                                         210.672776
# 27441                                         214.963975
# 27442                                         235.878443
# 27443                                         222.583928
# 27444                                         224.553441
# 27445                                         226.352898
# 27446                                         227.293633
# 27447                                         243.143812
# 27448                                         226.352898
# 27449                                         226.111684
# 27450                                         225.473673
# 27451                                         225.150446
# 27452                                         224.659575
# 27453                                         222.007426
# 27454                                         219.216579
# 27457                                         209.701889
# 27458                                         207.293366
# 27459                                         202.689795
# 27462                                         187.821358
# 27463                                         181.828394
# 27464                                         176.497562
# 27465                                         170.751843
# 27466                                         164.933758
# 27467                                         160.853622
# 27468                                         156.359803
# 27469                                         152.471432
# 27470                                         146.494147
# 27471                                         142.428483

# %%
# df.where() preserves the size of dataframe. It fills every column of non-matching rows with 0.
df_iran.where(df_iran.cases > 13000, np.nan)
# Out:
#                    dateRep  day  month  year  cases  deaths  \
# 27440                    0    0      0     0      0       0
# 27441                    0    0      0     0      0       0
# 27442                    0    0      0     0      0       0
# 27443                    0    0      0     0      0       0
# 27444                    0    0      0     0      0       0
# 27445                    0    0      0     0      0       0
# 27446  2020-12-05 00:00:00    5     12  2020  13341     347
# 27447  2020-12-04 00:00:00    4     12  2020  13922     358
# 27448  2020-12-03 00:00:00    3     12  2020  13621     362
# 27449  2020-12-02 00:00:00    2     12  2020  13881     382
# 27450  2020-12-01 00:00:00    1     12  2020  13321     371
# 27451                    0    0      0     0      0       0
# 27452  2020-11-29 00:00:00   29     11  2020  13402     391
# 27453  2020-11-28 00:00:00   28     11  2020  14051     406
# 27454  2020-11-27 00:00:00   27     11  2020  13961     482
# 27457                    0    0      0     0      0       0
# 27458  2020-11-23 00:00:00   23     11  2020  13053     475
# 27459                    0    0      0     0      0       0
# 27462  2020-11-19 00:00:00   19     11  2020  13421     480
# 27463  2020-11-18 00:00:00   18     11  2020  13352     482
# 27464  2020-11-17 00:00:00   17     11  2020  13053     486
# 27465                    0    0      0     0      0       0
# 27466                    0    0      0     0      0       0
# 27467                    0    0      0     0      0       0
# 27468                    0    0      0     0      0       0
# 27469                    0    0      0     0      0       0
# 27470                    0    0      0     0      0       0
# 27471                    0    0      0     0      0       0
#
#       countriesAndTerritories geoId countryterritoryCode  popData2019  \
# 27440                       0     0                    0          0.0
# 27441                       0     0                    0          0.0
# 27442                       0     0                    0          0.0
# 27443                       0     0                    0          0.0
# 27444                       0     0                    0          0.0
# 27445                       0     0                    0          0.0
# 27446                    Iran    IR                  IRN   82913893.0
# 27447                    Iran    IR                  IRN   82913893.0
# 27448                    Iran    IR                  IRN   82913893.0
# 27449                    Iran    IR                  IRN   82913893.0
# 27450                    Iran    IR                  IRN   82913893.0
# 27451                       0     0                    0          0.0
# 27452                    Iran    IR                  IRN   82913893.0
# 27453                    Iran    IR                  IRN   82913893.0
# 27454                    Iran    IR                  IRN   82913893.0
# 27457                       0     0                    0          0.0
# 27458                    Iran    IR                  IRN   82913893.0
# 27459                       0     0                    0          0.0
# 27462                    Iran    IR                  IRN   82913893.0
# 27463                    Iran    IR                  IRN   82913893.0
# 27464                    Iran    IR                  IRN   82913893.0
# 27465                       0     0                    0          0.0
# 27466                       0     0                    0          0.0
# 27467                       0     0                    0          0.0
# 27468                       0     0                    0          0.0
# 27469                       0     0                    0          0.0
# 27470                       0     0                    0          0.0
# 27471                       0     0                    0          0.0
#
#       continentExp  Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 27440            0                                           0.000000
# 27441            0                                           0.000000
# 27442            0                                           0.000000
# 27443            0                                           0.000000
# 27444            0                                           0.000000
# 27445            0                                           0.000000
# 27446         Asia                                         227.293633
# 27447         Asia                                         243.143812
# 27448         Asia                                         226.352898
# 27449         Asia                                         226.111684
# 27450         Asia                                         225.473673
# 27451            0                                           0.000000
# 27452         Asia                                         224.659575
# 27453         Asia                                         222.007426
# 27454         Asia                                         219.216579
# 27457            0                                           0.000000
# 27458         Asia                                         207.293366
# 27459            0                                           0.000000
# 27462         Asia                                         187.821358
# 27463         Asia                                         181.828394
# 27464         Asia                                         176.497562
# 27465            0                                           0.000000
# 27466            0                                           0.000000
# 27467            0                                           0.000000
# 27468            0                                           0.000000
# 27469            0                                           0.000000
# 27470            0                                           0.000000
# 27471            0                                           0.000000

# %% [markdown]
# ## Adding A New Column

# %%
# calculating death/cases ratio
df_iran['ratio'] = df_iran.deaths / df_iran.cases
df_iran.head()
# Out:
# <ipython-input-50-349be5621f87>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_iran['ratio'] = df_iran.deaths / df_iran.cases
#          dateRep  ratio_percent  day  month  year  cases  deaths  \
# 27440 2020-12-11       2.729982   11     12  2020  10403     284
# 27441 2020-12-10       2.885650   10     12  2020  10223     295
# 27442 2020-12-09       2.930237    9     12  2020  11023     323
# 27443 2020-12-08       2.623072    8     12  2020  10827     284
# 27444 2020-12-07       2.543033    7     12  2020  11561     294
#
#       countriesAndTerritories geoId countryterritoryCode  popData2019  \
# 27440                    Iran    IR                  IRN   82913893.0
# 27441                    Iran    IR                  IRN   82913893.0
# 27442                    Iran    IR                  IRN   82913893.0
# 27443                    Iran    IR                  IRN   82913893.0
# 27444                    Iran    IR                  IRN   82913893.0
#
#       continentExp  \
# 27440         Asia
# 27441         Asia
# 27442         Asia
# 27443         Asia
# 27444         Asia
#
#        Cumulative_number_for_14_days_of_COVID-19_cases_per_100000     ratio
# 27440                                         210.672776           0.027300
# 27441                                         214.963975           0.028857
# 27442                                         235.878443           0.029302
# 27443                                         222.583928           0.026231
# 27444                                         224.553441           0.025430

# %%
# method 2
df_iran.insert(1, 'ratio_percent', df_iran.ratio * 100)
df_iran.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-e8501a3bd85a> in <module>
#       1 # method 2
# ----> 2 df_iran.insert(1, 'ratio_percent', df_iran.ratio * 100)
#       3 df_iran.head()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3622         self._ensure_valid_index(value)
#    3623         value = self._sanitize_column(column, value, broadcast=False)
# -> 3624         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3625
#    3626     def assign(self, **kwargs) -> "DataFrame":
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1175         if not allow_duplicates and item in self.items:
#    1176             # Should this be a different kind of error??
# -> 1177             raise ValueError(f"cannot insert {item}, already exists")
#    1178
#    1179         if not isinstance(loc, int):
#
# ValueError: cannot insert ratio_percent, already exists

# %% [markdown]
# ## Deleting A Column

# %%
df_iran.drop(columns=['ratio', 'ratio_percent'])
df_iran.head()  # nothing is dropped

df_iran.drop(columns=['ratio', 'ratio_percent'], inplace=True)      # Notice the inplace argument
df.head()
# Out:
# /Users/Rooholah/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-12-14   14     12  2020    746       6             Afghanistan    AF
# 1 2020-12-13   13     12  2020    298       9             Afghanistan    AF
# 2 2020-12-12   12     12  2020    113      11             Afghanistan    AF
# 3 2020-12-11   11     12  2020     63      10             Afghanistan    AF
# 4 2020-12-10   10     12  2020    202      16             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
# 3                  AFG   38041757.0         Asia
# 4                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# 1                                           7.052776
# 2                                           6.868768
# 3                                           7.134266
# 4                                           6.968658

# %% [markdown]
# ## Renaming A Column

# %%
df_iran.rename(columns={
    'Cumulative_number_for_14_days_of_COVID-19_cases_per_100000': 'cum_num_14_per_100000'
}, inplace=True)
# Out:
# /Users/Rooholah/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# ## Adding A Row

# %%
df_iran.head()
# Out:
#          dateRep  ratio_percent  day  month  year  cases  deaths  \
# 27440 2020-12-11       2.729982   11     12  2020  10403     284
# 27441 2020-12-10       2.885650   10     12  2020  10223     295
# 27442 2020-12-09       2.930237    9     12  2020  11023     323
# 27443 2020-12-08       2.623072    8     12  2020  10827     284
# 27444 2020-12-07       2.543033    7     12  2020  11561     294
#
#       countriesAndTerritories geoId countryterritoryCode  popData2019  \
# 27440                    Iran    IR                  IRN   82913893.0
# 27441                    Iran    IR                  IRN   82913893.0
# 27442                    Iran    IR                  IRN   82913893.0
# 27443                    Iran    IR                  IRN   82913893.0
# 27444                    Iran    IR                  IRN   82913893.0
#
#       continentExp  cum_num_14_per_100000     ratio
# 27440         Asia             210.672776  0.027300
# 27441         Asia             214.963975  0.028857
# 27442         Asia             235.878443  0.029302
# 27443         Asia             222.583928  0.026231
# 27444         Asia             224.553441  0.025430

# %%
df_iran.loc[len(df)] = ['2020-12-14 00:00:00',	14,	12,	2020,	7451,	247,	'Iran',	'IR',	'IRN',	82913893.0,	'Asia',	192.392365]
df_iran.tail()
# Out:
# /Users/Rooholah/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)
#                    dateRep  day  month  year  cases  deaths  \
# 27468  2020-11-13 00:00:00   13     11  2020  11517     457
# 27469  2020-11-12 00:00:00   12     11  2020  11780     462
# 27470  2020-11-11 00:00:00   11     11  2020  10339     453
# 27471  2020-11-10 00:00:00   10     11  2020  10463     458
# 61900  2020-12-14 00:00:00   14     12  2020   7451     247
#
#       countriesAndTerritories geoId countryterritoryCode  popData2019  \
# 27468                    Iran    IR                  IRN   82913893.0
# 27469                    Iran    IR                  IRN   82913893.0
# 27470                    Iran    IR                  IRN   82913893.0
# 27471                    Iran    IR                  IRN   82913893.0
# 61900                    Iran    IR                  IRN   82913893.0
#
#       continentExp  cum_num_14_per_100000
# 27468         Asia             156.359803
# 27469         Asia             152.471432
# 27470         Asia             146.494147
# 27471         Asia             142.428483
# 61900         Asia             192.392365

# %%
df_iran.loc[61900]
# Out:
# dateRep                    2020-12-14 00:00:00
# day                                         14
# month                                       12
# year                                      2020
# cases                                     7451
# deaths                                     247
# countriesAndTerritories                   Iran
# geoId                                       IR
# countryterritoryCode                       IRN
# popData2019                        8.29139e+07
# continentExp                              Asia
# cum_num_14_per_100000                  192.392
# Name: 61900, dtype: object

# %% [markdown]
# ## Saving A DataFrame

# %%
df_iran.to_csv('iran_covid.csv', index=False)

# %% [markdown]
# ## Dealing With Categorical Data

# %%
df.dtypes
# Out:
# dateRep                                                       datetime64[ns]
# day                                                                    int64
# month                                                                  int64
# year                                                                   int64
# cases                                                                  int64
# deaths                                                                 int64
# countriesAndTerritories                                               object
# geoId                                                                 object
# countryterritoryCode                                                  object
# popData2019                                                          float64
# continentExp                                                          object
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000           float64
# dtype: object

# %%
df.memory_usage(deep=True).sum()/1e6    # Megabytes
# Out:
# 19.311064

# %%
df.countriesAndTerritories = df.countriesAndTerritories.astype('category')
df.geoId = df.geoId.astype('category')
df.countryterritoryCode = df.countryterritoryCode.astype('category')
df.continentExp = df.continentExp.astype('category')
print(df.dtypes)
df.memory_usage(deep=True).sum()/1e6    # How much less memory is being occupied!!!!
# Out:
# dateRep                                                       datetime64[ns]
# day                                                                    int64
# month                                                                  int64
# year                                                                   int64
# cases                                                                  int64
# deaths                                                                 int64
# countriesAndTerritories                                             category
# geoId                                                               category
# countryterritoryCode                                                category
# popData2019                                                          float64
# continentExp                                                        category
# Cumulative_number_for_14_days_of_COVID-19_cases_per_100000           float64
# dtype: object
# 4.460027
